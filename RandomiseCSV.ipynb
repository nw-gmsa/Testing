# %%
import pandas as pd

li=[]
# Read the CSV file
ney_data = pd.read_csv("Input/PDS/NEY.csv")

# View the first 5 rows
ney_data.head()
# Out:
#    NHS Number    Surname Forename  Middle name  Other Name Gender  \
# 0  9737873947  NEWCASTLE   Rheana          NaN         NaN      F
# 1  9737383222      LEEDS      Rob          NaN         NaN      M
# 2  9737873858  SHEFFIELD    Theon          NaN         NaN      M
# 3  9737873963       HULL     Yara          NaN         NaN      F
# 4  9737873866       YORK    Euron          NaN         NaN      M
#
#   Date Of Birth Deceased GP Surgery   Address line 1 Address line 2  \
# 0    11/06/2009      NaN     A89025            Byker      Newcastle
# 1    17/01/1978      NaN     B86016      Maison Lane            NaN
# 2    12/09/1986      NaN     C88622    SPITAL STREET      Sheffield
# 3    23/04/1981      NaN     B81061  4 Centurion Way         Brough
# 4    02/03/1982        ✅        NaN              NaN            NaN
#
#   Address line 3 Address line 4  Address line 5  Postcode
# 0            NaN            NaN             NaN   NE6 1SG
# ...

# %%
nw_data = pd.read_csv("Input/PDS/NW.csv")
nw_data.head()
# Out:
#      NHS Number     Surname Forename  Middle name                 Other Name  \
# 0  944 930 5552    CHISLETT  Octavia          NaN                        NaN
# 1    9737383192  MANCHESTER    Sansa          NaN                        NaN
# 2    9737383206   LIVERPOOL      Ned          NaN                        NaN
# 3    9737383214   LANCASTER    Jaime          NaN                          M
# 4    9737383230      LONDON   Cersei          NaN  Cersei LANCASTER (maiden)
#
#        Gender Date Of Birth Deceased     GP Surgery         Address line 1  \
# 0           F    20/09/2008      NaN            NaN  1 RAVENSFIELD GARDENS
# 1           F    21/09/1972      NaN         P84673              Oxford Rd
# 2           M    18/06/1942      NaN         N82035       20 Forthlin Road
# 3  27/07/1970           NaN   P81002  Dalton Square                    NaN
# 4           F    03/10/1973      NaN         F83004   110 The Queen's Walk
#
# ...

# %%
li.append(ney_data)
li.append(nw_data)

pds = pd.concat(li, axis=0, ignore_index=True)

pds
# Out:
#       NHS Number         Surname  Forename  Middle name  \
# 0     9737873947       NEWCASTLE    Rheana          NaN
# 1     9737383222           LEEDS       Rob          NaN
# 2     9737873858       SHEFFIELD     Theon          NaN
# 3     9737873963            HULL      Yara          NaN
# 4     9737873866            YORK     Euron          NaN
# 5     9737873971  MIDDLESBOROUGH   Allanys          NaN
# 6     9737873874      SUNDERLAND    Corlys          NaN
# 7     9737873998          DURHAM   Alicent          NaN
# 8     9737873882        BRADFORD    Rodrik          NaN
# 9   944 930 5552        CHISLETT   Octavia          NaN
# 10    9737383192      MANCHESTER     Sansa          NaN
# 11    9737383206       LIVERPOOL       Ned          NaN
# 12    9737383214       LANCASTER     Jaime          NaN
# 13    9737383230          LONDON    Cersei          NaN
# 14    9737383249      BIRMINGHAM    Tommen          NaN
# 15    9737383257         WREXHAM  Myrcella          NaN
# ...

# %%
import pandas as pd

# Read the CSV file
ctdna_data = pd.read_csv("NotGit/NEYGMSctDNAOrderData.csv")

# View the first 5 rows
ctdna_data.head()
# Out:
#    PatientAccessionIdentifier     NHSNumber HospitalNumber PatientFamilyName  \
# 0                      228731  450 008 5475     RXR3178922         McAlernon
# 1                       32737  454 067 5729     RXR0817610             Dixon
# 2                      336292  460 578 5590     RXR3302855           Wearden
# 3                      285232  408 363 1309         WL3847          Connelly
# 4                      336384  408 706 2473         658357          Westerby
#
#   PatientGivenName        DateOfBirth AdministrativeSex  \
# 0            Linda  18 Mar 1956 12:00            Female
# 1           Judith  05 Mar 1951 12:00            Female
# 2          Stephen  25 Mar 1952 12:00              Male
# 3    Caroline Mary  07 Dec 1975 12:00            Female
# 4          Heather  06 Nov 1981 12:00            Female
#
#   OrderingProviderIdentifier                  OrderingProviderName  \
# 0     Osama_El-Masri_7759129                     Dr Osama El-Masri
# ...

# %%
combined = pd.concat([ctdna_data, pds], axis=1)

combined.up
# Out:
#     PatientAccessionIdentifier     NHSNumber HospitalNumber PatientFamilyName  \
# 0                     228731.0  450 008 5475     RXR3178922         McAlernon
# 1                      32737.0  454 067 5729     RXR0817610             Dixon
# 2                     336292.0  460 578 5590     RXR3302855           Wearden
# 3                     285232.0  408 363 1309         WL3847          Connelly
# 4                     336384.0  408 706 2473         658357          Westerby
# 5                     336385.0  604 889 8681        1342615            Sassen
# 6                     334467.0  442 080 0666    RMC00177314           Scholes
# 7                     336389.0  408 785 9169         336577   Lambert-Cundall
# 8                          NaN           NaN            NaN               NaN
# 9                          NaN           NaN            NaN               NaN
# 10                         NaN           NaN            NaN               NaN
# ...
