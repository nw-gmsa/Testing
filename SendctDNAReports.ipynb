# %% [markdown]
# # Send ctDNA ORU R01 Reports
#
# Sends the 100 example ctDNA report messages generated in `Input/V2/R01/ctdna{NHSNumber}_{seq}.txt` to the v2 server.

# %%
import glob
import os
import requests
from dotenv import load_dotenv

load_dotenv()

v2Server = os.getenv("V2_SERVER")

# %%
report_list = sorted(
    os.path.basename(f)
    for f in glob.glob('Input/V2/R01/ctdna*_[0-9][0-9][0-9].txt')
)
len(report_list)
# Out:
# 130

# %%
for file in report_list:
    with open('Input/V2/R01/' + file, 'rb') as g:
        s = g.read()

        r = requests.post(v2Server, data = s)
        print(file)
        print(r.status_code)
        print(r.text)
# Out:
# ctdna9737383192_001.txt
# 200
# MSA|AR|3bca4018-8810-49ce-943c-b9982e8941c3ACK^R01|3bca4018-8810-49ce-943c-b9982e8941c3|P|2.5.1
# ctdna9737383192_002.txt
# 200
# MSA|AR|797777ba-b318-4764-88ab-179e5a226becACK^R01|797777ba-b318-4764-88ab-179e5a226bec|P|2.5.1
# ctdna9737383192_024.txt
# 200
# MSA|AR|c51bf423-f333-4de2-918f-c49593b320c3ACK^R01|c51bf423-f333-4de2-918f-c49593b320c3|P|2.5.1
# ctdna9737383192_032.txt
# 200
# MSA|AR|8824ec0f-96a9-4f9f-9b34-b5a1d0077e68ACK^R01|8824ec0f-96a9-4f9f-9b34-b5a1d0077e68|P|2.5.1
# ctdna9737383192_042.txt
# 200
# MSA|AR|0d883aec-17f6-4086-b6db-b736947df604ACK^R01|0d883aec-17f6-4086-b6db-b736947df604|P|2.5.1
# ctdna9737383192_054.txt
# 200
# MSA|AR|689cdef5-1c40-49f4-8e6b-9c99644f9626ACK^R01|689cdef5-1c40-49f4-8e6b-9c99644f9626|P|2.5.1
# ctdna9737383192_072.txt
# 200
# MSA|AR|fde3fcd2-6208-4d1e-85cb-8664c7044539ACK^R01|fde3fcd2-6208-4d1e-85cb-8664c7044539|P|2.5.1
# ctdna9737383206_016.txt
# 200
# MSA|AR|5ba50335-729a-47e2-87fd-459427289067ACK^R01|5ba50335-729a-47e2-87fd-459427289067|P|2.5.1
# ctdna9737383206_050.txt
# 200
# MSA|AR|8afd6c5c-9dd9-44dd-91bc-fd198b31c7a2ACK^R01|8afd6c5c-9dd9-44dd-91bc-fd198b31c7a2|P|2.5.1
# ctdna9737383206_073.txt
# 200
# MSA|AR|a9d8a781-ebef-488c-9f1f-f2e7aab417e2ACK^R01|a9d8a781-ebef-488c-9f1f-f2e7aab417e2|P|2.5.1
# ctdna9737383214_013.txt
# 200
# MSA|AR|0c5b5003-9e6a-46b9-9d44-5c7ac3a46c69ACK^R01|0c5b5003-9e6a-46b9-9d44-5c7ac3a46c69|P|2.5.1
# ctdna9737383214_027.txt
# 200
# MSA|AR|aadb7f3e-9058-4a2e-b1dd-c1a25e8c0068ACK^R01|aadb7f3e-9058-4a2e-b1dd-c1a25e8c0068|P|2.5.1
# ctdna9737383214_035.txt
# 200
# MSA|AR|4f0dafdd-7dae-44ae-b041-d50ff5eece2bACK^R01|4f0dafdd-7dae-44ae-b041-d50ff5eece2b|P|2.5.1
# ctdna9737383214_037.txt
# 200
# MSA|AR|9c57b4e7-9ccd-49d8-8787-778bfd362d9cACK^R01|9c57b4e7-9ccd-49d8-8787-778bfd362d9c|P|2.5.1
# ctdna9737383214_041.txt
# 200
# MSA|AR|a3d283ac-228f-4329-8c2c-958cbbee83d5ACK^R01|a3d283ac-228f-4329-8c2c-958cbbee83d5|P|2.5.1
# ctdna9737383214_075.txt
# 200
# MSA|AR|b93994a5-9bef-465f-8edc-43adbb678ab6ACK^R01|b93994a5-9bef-465f-8edc-43adbb678ab6|P|2.5.1
# ctdna9737383214_081.txt
# 200
# MSA|AR|8d833e02-839b-4c67-b5a9-172aeec31e45ACK^R01|8d833e02-839b-4c67-b5a9-172aeec31e45|P|2.5.1
# ctdna9737383214_085.txt
# 200
# MSA|AR|b8489efe-4f74-478b-bd30-c89cce9bf059ACK^R01|b8489efe-4f74-478b-bd30-c89cce9bf059|P|2.5.1

# %% [markdown]
# ## Send only the EDI Test Patient reports
#
# The 30 reports generated for the NHS England EDI test patients (NHS numbers starting `9999999`), requested from North Midlands trusts and London trusts around The Royal Marsden.

# %%
edi_report_list = sorted(
    os.path.basename(f)
    for f in glob.glob('Input/V2/R01/ctdna9999999*_[0-9][0-9][0-9].txt')
)
len(edi_report_list)

# %%
for file in edi_report_list:
    with open('Input/V2/R01/' + file, 'rb') as g:
        s = g.read()

        r = requests.post(v2Server, data = s)
        print(file)
        print(r.status_code)
        print(r.text)
