# %% [markdown]
# # Send ctDNA ORU R01 Reports
#
# Sends the 100 example ctDNA report messages generated in `Input/V2/R01/ctdna{NHSNumber}_{seq}.txt` to the v2 server.

# %%
import glob
import os
import requests
from dotenv import load_dotenv

load_dotenv()

v2Server = os.getenv("V2_SERVER")

# %%
report_list = sorted(
    os.path.basename(f)
    for f in glob.glob('Input/V2/R01/ctdna*_[0-9][0-9][0-9].txt')
)
len(report_list)
# Out:
# 130

# %%
for file in report_list:
    with open('Input/V2/R01/' + file, 'rb') as g:
        s = g.read()

        r = requests.post(v2Server, data = s)
        print(file)
        print(r.status_code)
        print(r.text)
# Out:
# ctdna9737383192_001.txt
# 200
# MSA|AR|3bca4018-8810-49ce-943c-b9982e8941c3ACK^R01|3bca4018-8810-49ce-943c-b9982e8941c3|P|2.5.1
# ctdna9737383192_002.txt
# 200
# MSA|AR|797777ba-b318-4764-88ab-179e5a226becACK^R01|797777ba-b318-4764-88ab-179e5a226bec|P|2.5.1
# ctdna9737383192_024.txt
# 200
# MSA|AR|c51bf423-f333-4de2-918f-c49593b320c3ACK^R01|c51bf423-f333-4de2-918f-c49593b320c3|P|2.5.1
# ctdna9737383192_032.txt
# 200
# MSA|AR|8824ec0f-96a9-4f9f-9b34-b5a1d0077e68ACK^R01|8824ec0f-96a9-4f9f-9b34-b5a1d0077e68|P|2.5.1
# ctdna9737383192_042.txt
# 200
# MSA|AR|0d883aec-17f6-4086-b6db-b736947df604ACK^R01|0d883aec-17f6-4086-b6db-b736947df604|P|2.5.1
# ctdna9737383192_054.txt
# 200
# MSA|AR|689cdef5-1c40-49f4-8e6b-9c99644f9626ACK^R01|689cdef5-1c40-49f4-8e6b-9c99644f9626|P|2.5.1
# ctdna9737383192_072.txt
# 200
# MSA|AR|fde3fcd2-6208-4d1e-85cb-8664c7044539ACK^R01|fde3fcd2-6208-4d1e-85cb-8664c7044539|P|2.5.1
# ctdna9737383206_016.txt
# 200
# MSA|AR|5ba50335-729a-47e2-87fd-459427289067ACK^R01|5ba50335-729a-47e2-87fd-459427289067|P|2.5.1
# ctdna9737383206_050.txt
# 200
# MSA|AR|8afd6c5c-9dd9-44dd-91bc-fd198b31c7a2ACK^R01|8afd6c5c-9dd9-44dd-91bc-fd198b31c7a2|P|2.5.1
# ctdna9737383206_073.txt
# 200
# MSA|AR|a9d8a781-ebef-488c-9f1f-f2e7aab417e2ACK^R01|a9d8a781-ebef-488c-9f1f-f2e7aab417e2|P|2.5.1
# ctdna9737383214_013.txt
# 200
# MSA|AR|0c5b5003-9e6a-46b9-9d44-5c7ac3a46c69ACK^R01|0c5b5003-9e6a-46b9-9d44-5c7ac3a46c69|P|2.5.1
# ctdna9737383214_027.txt
# 200
# MSA|AR|aadb7f3e-9058-4a2e-b1dd-c1a25e8c0068ACK^R01|aadb7f3e-9058-4a2e-b1dd-c1a25e8c0068|P|2.5.1
# ctdna9737383214_035.txt
# 200
# MSA|AR|4f0dafdd-7dae-44ae-b041-d50ff5eece2bACK^R01|4f0dafdd-7dae-44ae-b041-d50ff5eece2b|P|2.5.1
# ctdna9737383214_037.txt
# 200
# MSA|AR|9c57b4e7-9ccd-49d8-8787-778bfd362d9cACK^R01|9c57b4e7-9ccd-49d8-8787-778bfd362d9c|P|2.5.1
# ctdna9737383214_041.txt
# 200
# MSA|AR|a3d283ac-228f-4329-8c2c-958cbbee83d5ACK^R01|a3d283ac-228f-4329-8c2c-958cbbee83d5|P|2.5.1
# ctdna9737383214_075.txt
# 200
# MSA|AR|b93994a5-9bef-465f-8edc-43adbb678ab6ACK^R01|b93994a5-9bef-465f-8edc-43adbb678ab6|P|2.5.1
# ctdna9737383214_081.txt
# 200
# MSA|AR|8d833e02-839b-4c67-b5a9-172aeec31e45ACK^R01|8d833e02-839b-4c67-b5a9-172aeec31e45|P|2.5.1
# ctdna9737383214_085.txt
# 200
# MSA|AR|b8489efe-4f74-478b-bd30-c89cce9bf059ACK^R01|b8489efe-4f74-478b-bd30-c89cce9bf059|P|2.5.1
# ctdna9737383222_030.txt
# 200
# MSA|AR|4fb4e8b2-4cfb-4f09-86dc-fddfb49b9bffACK^R01|4fb4e8b2-4cfb-4f09-86dc-fddfb49b9bff|P|2.5.1
# ctdna9737383222_047.txt
# 200
# MSA|AR|a6ce1fdb-16fb-4067-86be-9d8fc6cb750bACK^R01|a6ce1fdb-16fb-4067-86be-9d8fc6cb750b|P|2.5.1
# ctdna9737383222_048.txt
# 200
# MSA|AR|06cb2b93-4324-4dd6-b58c-5894f45e6477ACK^R01|06cb2b93-4324-4dd6-b58c-5894f45e6477|P|2.5.1
# ctdna9737383222_068.txt
# 200
# ERR|||exception|error|||ERROR #5035: General exception Name 'Processing Exception' Code '502' Data 'Processing exception'
# ctdna9737383222_086.txt
# 200
# MSA|AR|eae7aeef-3989-4e84-80b8-1d1f19a8d258ACK^R01|eae7aeef-3989-4e84-80b8-1d1f19a8d258|P|2.5.1
# ctdna9737383222_090.txt
# 200
# MSA|AR|75373ea6-fd52-4a03-8e09-94f56b9bd872ACK^R01|75373ea6-fd52-4a03-8e09-94f56b9bd872|P|2.5.1
# ctdna9737383230_043.txt
# 200
# MSA|AR|286d0cf2-065a-41a1-8064-6b14555e4a1eACK^R01|286d0cf2-065a-41a1-8064-6b14555e4a1e|P|2.5.1
# ctdna9737383249_031.txt
# 200
# MSA|AR|9f358822-193b-4a5e-84e1-b2b80d91ea88ACK^R01|9f358822-193b-4a5e-84e1-b2b80d91ea88|P|2.5.1
# ctdna9737383257_019.txt
# 200
# MSA|AR|96efe6e9-e956-47b3-98c5-d3db696685a3ACK^R01|96efe6e9-e956-47b3-98c5-d3db696685a3|P|2.5.1
# ctdna9737383257_029.txt
# 200
# MSA|AR|59f5d674-c1b6-48ee-890a-3cb77a93643dACK^R01|59f5d674-c1b6-48ee-890a-3cb77a93643d|P|2.5.1
# ctdna9737383257_034.txt
# 200
# MSA|AR|0bafda82-a60f-40fc-bd58-dd5bf3b9a40eACK^R01|0bafda82-a60f-40fc-bd58-dd5bf3b9a40e|P|2.5.1
# ctdna9737383257_089.txt
# 200
# MSA|AR|f68f9adc-3f11-47cc-a78e-ddff03ae74aaACK^R01|f68f9adc-3f11-47cc-a78e-ddff03ae74aa|P|2.5.1
# ctdna9737383273_012.txt
# 200
# MSA|AR|c13f5ca0-b158-45fc-9c14-1e2bd3c1399aACK^R01|c13f5ca0-b158-45fc-9c14-1e2bd3c1399a|P|2.5.1
# ctdna9737383273_036.txt
# 200
# MSA|AR|0c948384-4233-4604-bbf9-8cc757cd2a81ACK^R01|0c948384-4233-4604-bbf9-8cc757cd2a81|P|2.5.1
# ctdna9737383273_065.txt
# 200
# MSA|AR|1bfb5e8d-9156-476a-95dc-a5b8fbaf8facACK^R01|1bfb5e8d-9156-476a-95dc-a5b8fbaf8fac|P|2.5.1
# ctdna9737383273_076.txt
# 200
# MSA|AR|3008435d-a818-4472-b2cd-6f0f1184798fACK^R01|3008435d-a818-4472-b2cd-6f0f1184798f|P|2.5.1
# ctdna9737383273_095.txt
# 200
# MSA|AR|e215ba28-bd7e-4a07-92d9-16954be34d33ACK^R01|e215ba28-bd7e-4a07-92d9-16954be34d33|P|2.5.1
# ctdna9737383281_033.txt
# 200
# ERR|||exception|error|||ERROR #5035: General exception Name 'Processing Exception' Code '502' Data 'Processing exception'
# ctdna9737383281_040.txt
# 200
# MSA|AR|ae164984-22a5-4569-920c-3e738d58ee8fACK^R01|ae164984-22a5-4569-920c-3e738d58ee8f|P|2.5.1
# ctdna9737383281_049.txt
# 200
# MSA|AR|e6569f14-d8be-4448-a03c-cd531334797eACK^R01|e6569f14-d8be-4448-a03c-cd531334797e|P|2.5.1
# ctdna9737383281_074.txt
# 200
# MSA|AR|304b7197-4de7-4317-93e1-1886acd3289bACK^R01|304b7197-4de7-4317-93e1-1886acd3289b|P|2.5.1
# ctdna9737383311_062.txt
# 200
# MSA|AR|56b9bee8-03f4-4894-b71b-789475bada5eACK^R01|56b9bee8-03f4-4894-b71b-789475bada5e|P|2.5.1
# ctdna9737383311_092.txt
# 200
# MSA|AR|8d4ebe95-a549-4b22-a324-932996b9ab18ACK^R01|8d4ebe95-a549-4b22-a324-932996b9ab18|P|2.5.1
# ctdna9737383338_008.txt
# 200
# MSA|AR|42f14647-600c-4bb0-9630-eb18e50778bbACK^R01|42f14647-600c-4bb0-9630-eb18e50778bb|P|2.5.1
# ctdna9737383338_017.txt
# 200
# MSA|AR|34d515f2-fba2-494b-8ba0-2f769966cef3ACK^R01|34d515f2-fba2-494b-8ba0-2f769966cef3|P|2.5.1
# ctdna9737383338_039.txt
# 200
# MSA|AR|a4cd10c7-5428-4b76-a00e-46645de8b957ACK^R01|a4cd10c7-5428-4b76-a00e-46645de8b957|P|2.5.1
# ctdna9737383338_051.txt
# 200
# MSA|AR|5ce47987-dca5-4d25-a157-f30cde4e7574ACK^R01|5ce47987-dca5-4d25-a157-f30cde4e7574|P|2.5.1
# ctdna9737383338_063.txt
# 200
# MSA|AR|4284c84e-c8f6-4685-90ed-6b7b1f52e18eACK^R01|4284c84e-c8f6-4685-90ed-6b7b1f52e18e|P|2.5.1
# ctdna9737383338_071.txt
# 200
# MSA|AR|81ef101c-b220-43a0-94e3-1c803324910cACK^R01|81ef101c-b220-43a0-94e3-1c803324910c|P|2.5.1
# ctdna9737383346_009.txt
# 200
# MSA|AR|005a6d10-7781-4910-955c-e03656643447ACK^R01|005a6d10-7781-4910-955c-e03656643447|P|2.5.1
# ctdna9737383346_064.txt
# 200
# MSA|AR|41ddd281-159c-40a3-81be-06cf4498c2feACK^R01|41ddd281-159c-40a3-81be-06cf4498c2fe|P|2.5.1
# ctdna9737383346_069.txt
# 200
# MSA|AR|0c3b9f9f-b34b-4a5f-bffe-3073a219a6aeACK^R01|0c3b9f9f-b34b-4a5f-bffe-3073a219a6ae|P|2.5.1
# ctdna9737383346_098.txt
# 200
# MSA|AR|a9b58fd0-95b8-49d5-910c-d671206101acACK^R01|a9b58fd0-95b8-49d5-910c-d671206101ac|P|2.5.1
# ctdna9737383354_022.txt
# 200
# MSA|AR|40f1ed08-ea20-412e-8ed6-a68280076e58ACK^R01|40f1ed08-ea20-412e-8ed6-a68280076e58|P|2.5.1
# ctdna9737383354_023.txt
# 200
# MSA|AR|e91dc349-0f97-4074-8f0a-3db45ded2f74ACK^R01|e91dc349-0f97-4074-8f0a-3db45ded2f74|P|2.5.1
# ctdna9737383354_091.txt
# 200
# MSA|AR|8a5d1d8d-4682-42aa-81fd-f2df1f7788dfACK^R01|8a5d1d8d-4682-42aa-81fd-f2df1f7788df|P|2.5.1
# ctdna9737383362_006.txt
# 200
# MSA|AR|18693447-902c-4670-a494-69727070310aACK^R01|18693447-902c-4670-a494-69727070310a|P|2.5.1
# ctdna9737383362_028.txt
# 200
# MSA|AR|99f2fae4-ac95-4d66-85a2-e93b80f340b7ACK^R01|99f2fae4-ac95-4d66-85a2-e93b80f340b7|P|2.5.1
# ctdna9737383362_044.txt
# 200
# MSA|AR|34f48f7c-5ed3-4ea7-92e8-f32f70dda7feACK^R01|34f48f7c-5ed3-4ea7-92e8-f32f70dda7fe|P|2.5.1
# ctdna9737383362_056.txt
# 200
# MSA|AR|6a9be528-9f38-4774-96bd-4f4b2d7bba80ACK^R01|6a9be528-9f38-4774-96bd-4f4b2d7bba80|P|2.5.1
# ctdna9737383362_060.txt
# 200
# MSA|AR|65834d4d-bbf9-4dd4-ac6b-f9d135bbdbd1ACK^R01|65834d4d-bbf9-4dd4-ac6b-f9d135bbdbd1|P|2.5.1
# ctdna9737383370_003.txt
# 200
# MSA|AR|ff7fd4f8-1aba-40f5-85f4-f2a526b19edcACK^R01|ff7fd4f8-1aba-40f5-85f4-f2a526b19edc|P|2.5.1
# ctdna9737383370_014.txt
# 200
# MSA|AR|e23ca6c8-d3a0-42e6-97e3-ebd4d1d06e2dACK^R01|e23ca6c8-d3a0-42e6-97e3-ebd4d1d06e2d|P|2.5.1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_91344/2336571000.py in <module>
#       1 for file in report_list:
# ----> 2     with open('Input/V2/R01/' + file, 'rb') as g:
#       3         s = g.read()
#       4
#       5         r = requests.post(v2Server, data = s)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Input/V2/R01/ctdna9737383370_020.txt'

# %% [markdown]
# ## Send only the EDI Test Patient reports
#
# The 30 reports generated for the NHS England EDI test patients (NHS numbers starting `9999999`), requested from North Midlands trusts and London trusts around The Royal Marsden.

# %%
edi_report_list = sorted(
    os.path.basename(f)
    for f in glob.glob('Input/V2/R01/ctdna9999999*_[0-9][0-9][0-9].txt')
)
len(edi_report_list)

# %%
for file in edi_report_list:
    with open('Input/V2/R01/' + file, 'rb') as g:
        s = g.read()

        r = requests.post(v2Server, data = s)
        print(file)
        print(r.status_code)
        print(r.text)
