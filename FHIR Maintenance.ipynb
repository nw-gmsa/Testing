# %%
import requests
import os
from dotenv import load_dotenv
from requests.auth import HTTPBasicAuth

validationEnabled = False

load_dotenv()

v2Server = os.getenv("V2_SERVER")
fhirServer = os.getenv("FHIR_SERVER")
toolsServer = os.getenv("V2_TOOLS")

tokenUrl = os.getenv("OAUTH2_TOKEN")
clientId = os.getenv("CLIENT_ID")
clientSecret = os.getenv("CLIENT_SECRET")

the_data = {"grant_type": "client_credentials", "scope": "system/*.*"}
headers = {'Content-Type': 'application/x-www-form-urlencoded'}
response = requests.post(tokenUrl, auth=HTTPBasicAuth(clientId, clientSecret),verify=False,data=the_data, headers=headers)
responseInclude = response.json()
token = responseInclude['access_token']

print(token)
print("token was displayed")
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjEifQ..DLy5c6vQ5y9o1JP2qLeXiVSTCa3TiWYlM1bhUdfEy47YUKuyexT6Qlt-xX1_iqK-gtXL33R8_WXxmDSMVieA-AzxN93n11DwYS638oWZtS2SX6OFCDlqN_FgjOT-mWPApGdZcXWLeuxNagcLE-SB-PGQ-TUq-bAWjRF-JSi0ayelABay68T3Ujlk3p2qGGt-aJDrdugQBEVZ4WIf7GaONxVbbQqNxPKcsxXrnHEpWaQcaRpbnxn_0iQ1-8pEQZCtZLoYkgkmrxiuz2rMS8Nk6pdDcdYk8LdzeXmJqFoVumbnvS1qoQ98PBkCkuNksoVYUKp0c2SVnOL-XWf2NGcFAw
# token was displayed
# ...

# %%
import requests, base64

userpass = 'sqluser:demo123'
encoded_userpass = base64.b64encode(userpass.encode()).decode()
headersFHIR = {'Content-Type': 'application/fhir+json',"Authorization": "Basic %s" % encoded_userpass}
cdrServer = 'https://192.168.1.20/healthconnect/cdr/fhir/r4/'

url = cdrServer + 'Observation?identifier=190000041:27491'
print(url)
response = requests.get(url, verify=False, headers=headersFHIR)
##print(response.status_code)
if response.status_code == 200:
    print('ok')
    response1JSON = response.json()
    print(response1JSON['total'])
    for entry in response1JSON['entry']:
         print(entry['resource']['id'])
         url = url = cdrServer + 'Observation/' +entry['resource']['id']
         print(url)
         requests.delete(url,verify=False,headers=headersFHIR)
print(response.status_code)
# Out:
# https://192.168.1.20/healthconnect/cdr/fhir/r4/Observation?identifier=190000041:27491
# ok
# 26
# 2581
# https://192.168.1.20/healthconnect/cdr/fhir/r4/Observation/2581
# 2582
# https://192.168.1.20/healthconnect/cdr/fhir/r4/Observation/2582
# 2583
# https://192.168.1.20/healthconnect/cdr/fhir/r4/Observation/2583
# 2584
# https://192.168.1.20/healthconnect/cdr/fhir/r4/Observation/2584
# 2585
# https://192.168.1.20/healthconnect/cdr/fhir/r4/Observation/2585
# /Users/kevinmayfield/Documents/GitHub/NHSNorthWestGMSA/Testing/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '192.168.1.20'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
