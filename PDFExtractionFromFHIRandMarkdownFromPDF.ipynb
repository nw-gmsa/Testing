# %% [markdown]
# # Extracting Markdown and PDF from FHIR Orders/Reports

# %%
import fhirclient.models.binary as bin
import json

from pypdf import PdfReader
import pymupdf
import base64
import io
import pymupdf4llm
import pathlib
import tabula

report_list = ['ORU_R01_DLIMS.txt','ORU_R01_R125.1_R0A.txt','ORU_R01_R125.1_RBS.txt','ORU_R01_R125.1_REP.txt','ORU_R01_R125.1_RR8.txt','ORU_R01_R125.1_RX1.txt','ORU_R01_R125.1_SG9.txt','ORU_R01_R125.1_ZT001.txt','ORU_R01_R125.1_7A3.txt','ORU_R01_R125.1_RPY.txt','ORU_R01_R125.1_RXK.txt', 'SHIRE_ORU_R01_RM3.txt', 'WALES_ORU_R01_TX.txt','LRI-GeneVariant-1.txt','LRI-GeneVariant-2.txt']

# For testing

#report_list = ['ORU_R01_R125.1_R0A.txt','ORU_R01_DLIMS.txt']


pdfReaderEnabled = False
pdfPymupdfEnabled = False
pdfpymupdf4llmEnabled = True
pdfTableEnabled = False


for file in report_list:
    with open('Output/FHIR/R01/' + file+ '.json', 'rb') as g:
        rawJson = g.read()
        jsonBundle = json.loads(rawJson)

        #bundle = b.Bundle(jsonBundle)
        for entry in jsonBundle['entry']:
            #print(entry['resource']['resourceType'])
            if entry['resource']['resourceType'] == 'Binary':
                binary = bin.Binary(entry['resource'])
                encoded = binary.data
                #print(encoded)
                decode = base64.b64decode(encoded)
                pdf_stream = io.BytesIO(decode)
                if pdfpymupdf4llmEnabled:
                    doc = pymupdf.open("pdf", pdf_stream)
                    md_text = pymupdf4llm.to_markdown(doc)
                    #print(md_text)
                    pathlib.Path('Output/Markdown/R01/' + file+ '.md').write_bytes(md_text.encode())
                if pdfPymupdfEnabled:
                    # https://pymupdf.readthedocs.io/en/latest/the-basics.html

                    # Initial Tests indicate this is the best method to use.

                    doc = pymupdf.open("pdf", pdf_stream)
                    print('Pages: '+ str(len(doc)))
                    print('============ pymupdf ' + file + ' ==============')
                    for page in doc: # iterate the document pages
                        text = page.get_text().encode("utf8")
                        print(text)
                if pdfReaderEnabled:
                    pdf = PdfReader(pdf_stream)
                    print('Pages: '+ str(len(pdf.pages)))
                    print('============ PDF Reader ' + file + ' ==============')
                    for page in pdf.pages:
                        text = page.extract_text()
                        # print(text)
                if pdfTableEnabled:
                    tables = tabula.read_pdf(pdf_stream
                                             , pages='all', multiple_tables=True)
                    print('============ Tabula ' + file + ' ==============')
                    for table in tables:
                        tab1 = table
                        #print(table)
                with open('Output/PDF/R01/' + file+ '.pdf', 'wb') as pdf:
                    pdf.write(decode)

# %% [markdown]
# # Extracting Markdown from PDF

# %%
pdf_list = ['R24-0WH7-1.pdf','R24-1A4W-1.pdf']

for file in pdf_list:
    with open('Output/PDF/R01/' + file, 'rb') as g:
        pdf_stream = g.read()
        if pdfpymupdf4llmEnabled:
            doc = pymupdf.open("pdf", pdf_stream)
            md_text = pymupdf4llm.to_markdown(doc)
            print(md_text)
            pathlib.Path('Output/Markdown/R01/' + file+ '.md').write_bytes(md_text.encode())


pdf_list = ['genomic-medicine-device-test-order-form-cancer-v1.22.pdf']

for file in pdf_list:
    with open('Output/PDF/O21/' + file, 'rb') as g:
        pdf_stream = g.read()
        if pdfpymupdf4llmEnabled:
            doc = pymupdf.open("pdf", pdf_stream)
            md_text = pymupdf4llm.to_markdown(doc)
            print(md_text)
            pathlib.Path('Output/Markdown/O21/' + file+ '.md').write_bytes(md_text.encode())
# Out:
# NHS Genomic Medicine Service, WGS Test Request Cancer, July 2024 v1.22 to be used for WGS go-live.
# This document is subject to version control and is regularly updated. Please confirm you are using the current version by
# contacting your local Genomic Laboratory Hub
#
# ~~**Genomic Medicine Service**~~
#
#
#
#
#
#
#
#
# |Whole Genome Sequencing (WGS) Test Request PLEASE DO NOT USE FOR NON-WGS TESTS CANCER|Col2|
# |---|---|
# |**Requesting organisation:**<br> <br>|**Requesting organisation:**<br> <br>|
# |<br>~~**GLH laboratory to receive sample:**~~<br>North West|~~Test Required~~<br>**Whole Genome Sequencing **|
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# |GLH laboratory to receive sample: North West|Col2|Col3|Col4|Test Required Whole Genome Sequencing|Col6|Col7|
# |---|---|---|---|---|---|---|
# |~~Patient first name~~<br> <br>Myrcella|~~Patient first name~~<br> <br>Myrcella|~~Patient first name~~<br> <br>Myrcella|~~Patient first name~~<br> <br>Myrcella|~~Ethnicity~~<br>|~~Ethnicity~~<br>|~~Ethnicity~~<br>|
# |~~Patient last name~~<br> <br> <br>Wrexham|~~Patient last name~~<br> <br> <br>Wrexham|~~Patient last name~~<br> <br> <br>Wrexham|~~Patient last name~~<br> <br> <br>Wrexham|~~Test Directory Clinical Indication & code (cancer type &~~<br>~~sub-type)~~<br>**_The clinical indications listed at the bottom of the pick_**<br>**_list under 'NEW INDICATIONS' are not live for all NHS_**<br>**_GLHs. Please check with GLHs prior to ordering._**|~~Test Directory Clinical Indication & code (cancer type &~~<br>~~sub-type)~~<br>**_The clinical indications listed at the bottom of the pick_**<br>**_list under 'NEW INDICATIONS' are not live for all NHS_**<br>**_GLHs. Please check with GLHs prior to ordering._**|~~Test Directory Clinical Indication & code (cancer type &~~<br>~~sub-type)~~<br>**_The clinical indications listed at the bottom of the pick_**<br>**_list under 'NEW INDICATIONS' are not live for all NHS_**<br>**_GLHs. Please check with GLHs prior to ordering._**|
# |~~Date of birth~~_(dd/mm/yyyy)_ <br><br>16/10/1970|~~Date of birth~~_(dd/mm/yyyy)_ <br><br>16/10/1970|~~Hospital number~~<br>12345678|~~Hospital number~~<br>12345678|~~Hospital number~~<br>12345678|~~Hospital number~~<br>12345678|~~Hospital number~~<br>12345678|
# |~~Gender~~<br> Male<br> Female<br> Other<br><br>|~~Gender~~<br> Male<br> Female<br> Other<br><br>|~~Gender~~<br> Male<br> Female<br> Other<br><br>|~~Gender~~<br> Male<br> Female<br> Other<br><br>|Presentation status<br> First diagnosis<br> Recurrence / Relapse<br> Unknown <br>|Presentation status<br> First diagnosis<br> Recurrence / Relapse<br> Unknown <br>|Presentation status<br> First diagnosis<br> Recurrence / Relapse<br> Unknown <br>|
# |Postcode<br> <br>N<br>G<br>1<br>0<br>1<br>n<br>p|Postcode<br> <br>N<br>G<br>1<br>0<br>1<br>n<br>p|Postcode<br> <br>N<br>G<br>1<br>0<br>1<br>n<br>p|Postcode<br> <br>N<br>G<br>1<br>0<br>1<br>n<br>p|~~Additional clinical information (if required)~~<br>_E.g. previous tumours, molecular testing, and relevant treatment history with_<br>_date(s)_<br>Some clinical information|~~Additional clinical information (if required)~~<br>_E.g. previous tumours, molecular testing, and relevant treatment history with_<br>_date(s)_<br>Some clinical information|~~Additional clinical information (if required)~~<br>_E.g. previous tumours, molecular testing, and relevant treatment history with_<br>_date(s)_<br>Some clinical information|
# |~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|~~NHS number~~<br>~~Reason NHS Number not availab~~le:<br> Patient not eligible for NHS number (e.g. foreign national)<br> Other (provide reason):<br>|
# |~~**Solid tumour requests only**~~<br> <br> <br>|~~**Solid tumour requests only**~~<br> <br> <br>|~~**Solid tumour requests only**~~<br> <br> <br>|~~**Solid tumour requests only**~~<br> <br> <br>|~~**Solid tumour requests only**~~<br> <br> <br>|~~**Solid tumour requests only**~~<br> <br> <br>|~~**Solid tumour requests only**~~<br> <br> <br>|
# |~~Primary~~<br> Metastatic<br> Unknown<br> Lymphoma<br> <br>|~~Histopathology Lab ID~~<br> <br>1234567PATH|~~Histopathology Lab ID~~<br> <br>1234567PATH|~~Histopathology Lab ID~~<br> <br>1234567PATH|~~Additional tumour information (if relevant)~~<br>_E.g. site of metastasis (if metastatic), or unknown primary_<br> <br>|~~Additional tumour information (if relevant)~~<br>_E.g. site of metastasis (if metastatic), or unknown primary_<br> <br>|~~Additional tumour information (if relevant)~~<br>_E.g. site of metastasis (if metastatic), or unknown primary_<br> <br>|
# |~~Primary~~<br> Metastatic<br> Unknown<br> Lymphoma<br> <br>|~~Date of this diagnosis~~_(dd/mm/yyyy)_ <br>|~~Date of this diagnosis~~_(dd/mm/yyyy)_ <br>|~~Date of this diagnosis~~_(dd/mm/yyyy)_ <br>|~~Tumour topography ~~|~~Tumour morphology ~~|~~Tumour morphology ~~|
# |~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|~~**Haemato-oncology liquid tumour requests only**~~<br> <br> <br> <br> <br>|
# |~~ AML~~<br>~~ ALL~~<br>~~ Other (please specify):~~<br>|~~ AML~~<br>~~ ALL~~<br>~~ Other (please specify):~~<br>|~~ AML~~<br>~~ ALL~~<br>~~ Other (please specify):~~<br>|~~ AML~~<br>~~ ALL~~<br>~~ Other (please specify):~~<br>|~~ SIHMDS Lab ID~~<br>|~~Date of this diagnosis~~_(dd/mm/yyyy)_|~~Date of this diagnosis~~_(dd/mm/yyyy)_|
# |~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|~~**Complete for tumour samples**~~~~_(being sent to GLH DNA extraction lab)_~~ <br> <br> <br> <br>|
# |~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|~~ Fresh frozen tumour~~<br>~~ Bone marrow~~<br>~~ Blood (EDTA)~~<br>~~ Other (please specify):~~<br> <br>|
# |<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|<br> <br> <br> <br>~~_% malignant nuclei / blasts or equivalent in this sample (refer to sample handling guidance) must be provided below_~~<br> <br> <br> <br>|
# |~~ Sample ID~~|~~ Sample ID~~|~~ Sample ID~~|~~Collection date / time~~|~~% Malignant nuclei / blasts~~|~~% Malignant nuclei / blasts~~|~~If BM/PB provide volume~~<br>and nucleated cell count|
# |<br>SAMPLEID1|<br>SAMPLEID1|<br>SAMPLEID1|||||
# |~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|~~**Complete for germline samples**~~~~_(being sent to GLH DNA extraction lab)_ ~~<br> <br> <br> <br> <br>|
# |~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|~~ Blood (EDTA)~~<br>~~ Saliva~~<br>~~ Fibroblasts~~<br>~~ Skin biopsy~~<br>~~ Other (please specify):~~<br> <br> <br> <br>|
# |~~Sample ID~~|~~Sample ID~~|~~Sample ID~~|~~Collection date / time~~|~~Sample volume if applicable~~|~~Sample volume if applicable~~|~~Comments~~|
# ||||||||
# |~~**Responsible consultant **~~|~~**Responsible consultant **~~|~~**Responsible consultant **~~|~~**Responsible consultant **~~|<br>~~**Main contact (if different from responsible consultant)**~~|<br>~~**Main contact (if different from responsible consultant)**~~|<br>~~**Main contact (if different from responsible consultant)**~~|
# |<br>Name:<br>Department address:<br>Phone:<br>Email:|<br>Name:<br>Department address:<br>Phone:<br>Email:|<br>Name:<br>Department address:<br>Phone:<br>Email:|<br>Name:<br>Department address:<br>Phone:<br>Email:|~~Name:~~<br>Department address:<br>Phone:<br>Email:<br>|~~Name:~~<br>Department address:<br>Phone:<br>Email:<br>|~~Name:~~<br>Department address:<br>Phone:<br>Email:<br>|
#
#
# Patient conversation taken place; Record of Discussion form to follow
#
#
# Version 1.22 Page 1 of 1

# %%
#
import fhirclient.models.binary as bin
import json

from pypdf import PdfReader
import pymupdf
import base64
import io
import pymupdf4llm
import pathlib
import tabula

report_list = ['GMCRFixBinary']

# For testing

#report_list = ['ORU_R01_R125.1_R0A.txt','ORU_R01_DLIMS.txt']


pdfReaderEnabled = False
pdfPymupdfEnabled = False
pdfpymupdf4llmEnabled = True
pdfTableEnabled = False


for file in report_list:
    with open('NotGit/' + file+ '.json', 'rb') as g:
        rawJson = g.read()
        entry = json.loads(rawJson)


        binary = bin.Binary(entry)
        encoded = binary.data
        #print(encoded)
        decode = base64.b64decode(encoded)
        pdf_stream = io.BytesIO(decode)
        if pdfpymupdf4llmEnabled:
            doc = pymupdf.open("pdf", pdf_stream)
            md_text = pymupdf4llm.to_markdown(doc)
            print(md_text)
            pathlib.Path('Output/Markdown/R01/' + file+ '.md').write_bytes(md_text.encode())
        if pdfPymupdfEnabled:
            # https://pymupdf.readthedocs.io/en/latest/the-basics.html

            # Initial Tests indicate this is the best method to use.

            doc = pymupdf.open("pdf", pdf_stream)
            print('Pages: '+ str(len(doc)))
            print('============ pymupdf ' + file + ' ==============')
            for page in doc: # iterate the document pages
                text = page.get_text().encode("utf8")
                print(text)
        if pdfReaderEnabled:
            pdf = PdfReader(pdf_stream)
            print('Pages: '+ str(len(pdf.pages)))
            print('============ PDF Reader ' + file + ' ==============')
            for page in pdf.pages:
                text = page.extract_text()
                # print(text)
        if pdfTableEnabled:
            tables = tabula.read_pdf(pdf_stream
                                     , pages='all', multiple_tables=True)
            print('============ Tabula ' + file + ' ==============')
            for table in tables:
                tab1 = table
                #print(table)
        with open('Output/PDF/R01/' + file+ '.pdf', 'wb') as pdf:
            pdf.write(decode)
# Out:
# ...
# **North West Genomic Laboratory Hub (Manchester Site)**
# Manchester Centre for Genomic Medicine
# 6th Floor, St Mary's Hospital, Manchester, M13 9WL
# Scientific Operational Director: Dr E. Howard
# https://mft.nhs.uk/nwglh/ mft.genomics@nhs.net Tel +44(0) 161 276 6122
#
#
#
# Forename: **Linda**
#
# Surname: **Smith**
#
#
#
# Report No: **R26-0UEM-1**
# Hospital No: **02133302**
# Other No: **Not provided**
#
#
#
# Sex: **Female** Other No: **Not provided**
#
# DoB: **29/08/1955** Sample: **FFPE - Shavings** Sample2: **FFPE - Shavings**
#
#
#
# DoB: **29/08/1955** Sample: **FFPE - Shavings**
#
#
#
# NHS No: **448 939 0084**
#
# EPR Order ID: **1033147490** Path. No: **B26-015054-A1** Path.2 No: **B26-015054-A1**
#
#
#
# Collected: **Not provided** Received:
# Received2:
#
#
#
# **12/05/2026 09:02**
# **12/05/2026 09:02**
#
#
#
# Activated: **12/05/2026**
# Reported: **26/05/2026**
#
#
#
# Referred by: Dr Antonio Paiva-Correia, Histopathology, Wythenshawe Hospital, Wythenshawe, M23 9LT, (antonio.paivacorreia@mft.nhs.uk,
# mft.wythenshawe.histosecs@nhs.net)
#
# # **Genomics Laboratory Report**
#
#
# **Reason for Testing**
# This patient has been referred for Non-Small Cell Lung Cancer NGS - structural variant testing (M4.2).
# Additional test requested: Non-Small Cell Lung Cancer NGS - small variant testing (M4.1)
# Neoplastic cell content: 20-30%
# Test Directory Subpanel analysed: M4.2 – ROS1, RET, ALK, NTRK1, NTRK2, NTRK3 (essential target genes)
#
#
# **RESULT SUMMARY:**
#
#
# ANALYSIS FAILED
#
#
# **Result and Interpretation**
#
# We were unable to obtain a result with this pathology sample; this is likely to be due to insufficient cellular material being present in the
# section sent for analysis or poor preservation of RNA in the pathology block.
#
#
# Should NGS panel analysis still be required please send further material, preferably from a different pathology sample, if available. Please
# note that a minimum neoplastic cell content of 20% is recommended for this test.
#
#
# Note: Please see Page 2 for technical details of the analysis (App I).
#
#
# Reported By:
# Authorised By:
# Chaila Latham
# Genetic Technologist
#
#
# Chris Watt
# Principal Clinical Scientist
#
#
# Page 1 of 2
#
#
# Forename: **Linda** Report No: **R26-0UEM-1**
#
# Surname: **Smith** DoB: **29/08/1955**
#
#
# _**APPENDIX I - Test Methodology:**_
#
#
# _**Sample Type**_ _: FFPE-derived RNA from solid tumour tissue._
# _**Extraction Platform**_ _: Qiagen QIAsymphony automated extraction._
# _**Test Name**_ _: QIAseq RNA Fusion XP Panel for Solid Tumour Fusion Detection using PCR based single primer extension and unique molecular indexes._
# _**Sequencing Platform**_ _: Illumina NextSeq 550, paired-end 2 × 151bp._
# _**Test details:**_ _This assay targets fusion transcripts involving the following 101 genes, selected based on their known clinical and biological relevance in solid tumours,_
# _according to the National Genomic Test Directory. Fusion events involving known partner genes as well as novel/unannotated partners involving the target gene list may be_
# _detected._
# _**Gene List**_ _: ALK, BRAF, EML4, ERG, FGFR1, FGFR2, FGFR3, MAML2, MET, MYB, NFIB, NTRK1, NTRK2, NTRK3, PDGFRA, PDGFRB, RAF1, RET, ROS1, TFE3, TFEB._
# _**Reference Sequences:**_ _Stated for genes involved in a detected fusion. Reference genome: GRCh38._
# _**Bioinformatics and Data Analysis:**_ _Software: Qiagen CLC Genomics Workbench v23.0. Pipeline: Detect QIAseq Fusion XP workflow against hg38 human genome._
# _**Analytical Performance:**_ _Analytical Sensitivity: >95% for known fusions present in samples with sufficient RNA quality. Reproducibility: 100% concordance in intra- and inter-_
# _run duplicates for samples with known fusions and sufficient RNA quality._
# _**Assay Limitations:**_ _Samples with <20% tumour content may result in false negatives. Only fusions involving the predefined 101 genes are detectable. Rare fusions with_
# _uncommon, complex or cryptic breakpoints may not be detected by this assay. Clinically relevant fusions can only be detected where there are at least 10 fusion crossing_
# _reads identified in the panel enriched sample. Samples where no fusion is detected with less than 150 mean read coverage of 4 control genes will be failed due to a high_
# _likelihood that the RNA is not of sufficient quantity and/or integrity. Samples with greater than 5% DNA contamination are failed._
# _**Accreditation:**_ _This test is not UKAS accredited. The test has been validated within the laboratory._
# _Please contact the laboratory for additional details, if required._
#
#
# Page 2 of 2
